# %% [markdown]
# # PyCoMo Loopless FVA #
# This tutorial show-cases the use of loopless FVA.
#
# The expected runtime for this notebook is less than 10 minutes.

# %%
from pathlib import Path
import sys
import os
import cobra
import matplotlib.pyplot as plt
from cobra import Reaction, Metabolite, Model
from cobra.flux_analysis.loopless import add_loopless, loopless_solution
import pandas as pd
import numpy as np
import math 
import time
import warnings

# %%
path_root = "../src"  # Change path according to your PyCoMo location
sys.path.append(str(path_root))
import pycomo
# Out:
# 2024-07-08 16:35:38,824 - pycomo.helper.multiprocess - INFO - Multiprocess Logger initialized.
# 2024-07-08 16:35:38,824 - pycomo.pycomo_models - INFO - Logger initialized.

# %% [markdown]
# ## Community toy model ##
# This simple community toy model consists of two identical community members. Each member has a two step conversion of the starting metabolite A. The products of these conversions (B and C) can be secreted and taken up from the medium, thus allowing exchange and forming a cycle. The members also have a biomass reaction with substrates C and D (an additional substrate).

# %%
model_single = Model()
model_single.add_metabolites([Metabolite(i) for i in "ABCD"])

for met in model_single.metabolites:
    met.compartment = "c"

model_single.add_metabolites([Metabolite(i+"_e") for i in "ABCD"])

for i in "ABCD":
    model_single.metabolites.get_by_id(i+"_e").compartment = "e"

model_single.add_reactions([Reaction(i) for i in ["EX_A", "EX_B", "EX_C", "EX_D", "TP_A", "TP_B", "TP_C", "TP_D", "bio", "v1", "v2"]])

model_single.reactions.EX_A.add_metabolites({"A_e": 1})
model_single.reactions.EX_B.add_metabolites({"B_e": 1})
model_single.reactions.EX_C.add_metabolites({"C_e": 1})
model_single.reactions.EX_D.add_metabolites({"D_e": 1})
model_single.reactions.TP_A.add_metabolites({"A_e": -1, "A": 1})
model_single.reactions.TP_B.add_metabolites({"B_e": -1, "B": 1})
model_single.reactions.TP_C.add_metabolites({"C_e": -1, "C": 1})
model_single.reactions.TP_D.add_metabolites({"D_e": -1, "D": 1})
model_single.reactions.bio.add_metabolites({"C": -1, "D": -1})

model_single.reactions.v1.add_metabolites({"A": -1, "B": 1})
model_single.reactions.v2.add_metabolites({"B": -1, "C": 1})

model_single.reactions.TP_B.lower_bound = -500
model_single.reactions.TP_C.lower_bound = -500
model_single.reactions.v2.lower_bound = -1000

model_single.objective = 'bio'

# %% [markdown]
# ### Constructing the community model ###

# %%
single_org_models_toy = []
for name in ["model_a", "model_b"]:
    print(name)
    single_org_model = pycomo.SingleOrganismModel(model_single, name)
    single_org_models_toy.append(single_org_model)
# Out:
# model_a
# model_b

# %%
community_name = "toy_com"
com_model_obj_toy = pycomo.CommunityModel(single_org_models_toy, community_name)
com_model_obj_toy.convert_to_fixed_abundance()
# Out:
# No community model generated yet. Generating now:
# Note: no products in the objective function, adding biomass to it.
# Ignoring reaction 'EX_A_medium' since it already exists.
# Ignoring reaction 'EX_B_medium' since it already exists.
# Ignoring reaction 'EX_C_medium' since it already exists.
# Ignoring reaction 'EX_D_medium' since it already exists.
# Note: no products in the objective function, adding biomass to it.
# WARNING: no annotation overlap found for matching metabolite C. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite B. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite D. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite A. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# Generated community model.

# %%
com_model_obj_toy.medium = {'EX_A_medium': 1000.0, 'EX_D_medium': 1000.0}
com_model_obj_toy.apply_medium()
# Out:
# <Model toy_com at 0x1bd0803f070>

# %%
com_model_obj_toy.summary()
# Out:
# <h3>Objective</h3><p>1.0 community_biomass = 1000.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>A_medium</td>
#       <td>EX_A_medium</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>D_medium</td>
#       <td>EX_D_medium</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cpd11416_medium</td>
#       <td>community_biomass</td>
#       <td>-1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Loops in the toy model ###

# %%
com_model_obj_toy.get_loops()
# Out:
#                  reaction  min_flux  max_flux
# 0  model_a_TP_B_model_a_e    -500.0     500.0
# 1  model_a_TP_C_model_a_e    -500.0     500.0
# 2            model_a_TP_C    -500.0     500.0
# 3            model_a_TP_B    -500.0     500.0
# 4    model_a_v2_model_a_c    -500.0     500.0
# 5  model_b_TP_B_model_b_e    -500.0     500.0
# 6  model_b_TP_C_model_b_e    -500.0     500.0
# 7            model_b_TP_C    -500.0     500.0
# 8            model_b_TP_B    -500.0     500.0
# 9    model_b_v2_model_b_c    -500.0     500.0

# %% [markdown]
# ## FVA examples ##

# %% [markdown]
# ### FVA with loops ###
# Normal fva will include the loops including metabolites B and C, reaction v2 and the transporters of B and C in the solutions.
#
# The following scenarios and correct outcomes will be tested on a :
#  - No medium: no reaction can carry flux
#  - 100% objective value: reaction v2 carries maximum flux (500; = 1000 * 0.5 as normalized to equal abundance) and transport reactions of B and C are inactive
#  - 0% objective value: reactions v2 and transporters of B and C carry maximum flux (250, reverse also for transporters)
#  - 80% objective value: reaction v2 carries flux between 300 and 500. Transporter of B can be active between -200 and 200, transporter of C between -100 and 100. This solution arises by one member giving 200 of B to the other (keeping 300), which converts B to C with maximum flux of 500, then gives back 100 of C while keeping the required 400. This results in a biomass reaction of 400 for both (80% of 500).

# %% [markdown]
# #### COBRApy fva ####
# The loopless version of COBRApy cannot be used on PyCoMo community models, due to their bound-free reaction structure. The resulting solutions include the loop:

# %%
# %%time
with com_model_obj_toy.model:
    com_model_obj_toy.medium = {}
    com_model_obj_toy.apply_medium()
    fva = cobra.flux_analysis.flux_variability_analysis(com_model_obj_toy.model, 
                                                        com_model_obj_toy.model.reactions, 
                                                        fraction_of_optimum=0., 
                                                        loopless=True)
fva
# Out:
# CPU times: total: 125 ms
# Wall time: 9.38 s
#                                     minimum  maximum
# model_a_TP_A_model_a_e                  0.0      0.0
# model_a_TP_B_model_a_e               -250.0    250.0
# model_a_TP_C_model_a_e               -250.0    250.0
# model_a_TP_D_model_a_e                  0.0      0.0
# model_a_TP_A                            0.0      0.0
# ...                                     ...      ...
# SK_model_b_v2_model_b_c_ub              2.5      7.5
# SK_model_b_to_community_biomass_ub      5.0      5.0
# f_final                                 1.0      1.0
# abundance_reaction                      0.0      0.0
# community_biomass                       0.0      0.0
#
# [71 rows x 2 columns]

# %% [markdown]
# #### PyCoMo fva with loops ####
# The PyCoMo wrapper for fva will also include loops, when loopless mode is not activated

# %%
# %%time
com_model_obj_toy.medium = {'EX_A_medium': 1000.0, 'EX_D_medium': 1000.0}
com_model_obj_toy.apply_medium()
with com_model_obj_toy.model:
    com_model_obj_toy.medium = {}
    com_model_obj_toy.apply_medium()
    fva = com_model_obj_toy.run_fva(reactions=com_model_obj_toy.model.reactions, fraction_of_optimum=1., loopless=False)
fva
# Out:
# CPU times: total: 46.9 ms
# Wall time: 8.34 s
#                                                reaction_id  min_flux  max_flux
# model_a_TP_A_model_a_e              model_a_TP_A_model_a_e       0.0       0.0
# model_a_TP_B_model_a_e              model_a_TP_B_model_a_e    -250.0     250.0
# model_a_TP_C_model_a_e              model_a_TP_C_model_a_e    -250.0     250.0
# model_a_TP_D_model_a_e              model_a_TP_D_model_a_e       0.0       0.0
# EX_A_medium                                    EX_A_medium       0.0       0.0
# EX_B_medium                                    EX_B_medium       0.0       0.0
# EX_C_medium                                    EX_C_medium       0.0       0.0
# EX_D_medium                                    EX_D_medium       0.0       0.0
# model_a_to_community_biomass  model_a_to_community_biomass       0.0       0.0
# model_b_TP_A_model_b_e              model_b_TP_A_model_b_e       0.0       0.0
# model_b_TP_B_model_b_e              model_b_TP_B_model_b_e    -250.0     250.0
# model_b_TP_C_model_b_e              model_b_TP_C_model_b_e    -250.0     250.0
# model_b_TP_D_model_b_e              model_b_TP_D_model_b_e       0.0       0.0
# model_b_to_community_biomass  model_b_to_community_biomass       0.0       0.0
# community_biomass                        community_biomass       0.0       0.0

# %% [markdown]
# ### PyCoMo loopless fva ###
# The following examples show that the loopless fva implemented in PyCoMo leads to the correct solutions in the 4 test cases (no medium, 100% objective value, 0% objective value, 80% objective value)
#
# __Note:__ For larger (genome-scale, >4 members) it will be beneficial to use parallel processing for loopless FVA. The number of processes can be specified either using the cobrapy configuration object, or directly in the functions of PyCoMo, with the processes argument.

# %%
# %%time
with com_model_obj_toy.model:
    com_model_obj_toy.medium = {}
    com_model_obj_toy.apply_medium()
    fva = com_model_obj_toy.run_fva(reactions=com_model_obj_toy.model.reactions, fraction_of_optimum=0., loopless=True)
fva
# Out:
# 2024-07-08 15:15:50,863 - pycomo.helper.multiprocess - INFO - Processed 66.67% of fva steps
# CPU times: total: 141 ms
# Wall time: 8.57 s
#                                                reaction_id  min_flux  max_flux
# model_a_TP_A_model_a_e              model_a_TP_A_model_a_e       0.0       0.0
# model_a_TP_B_model_a_e              model_a_TP_B_model_a_e       0.0       0.0
# model_a_TP_C_model_a_e              model_a_TP_C_model_a_e       0.0       0.0
# model_a_TP_D_model_a_e              model_a_TP_D_model_a_e       0.0       0.0
# EX_A_medium                                    EX_A_medium       0.0      -0.0
# EX_B_medium                                    EX_B_medium       0.0      -0.0
# EX_C_medium                                    EX_C_medium       0.0      -0.0
# EX_D_medium                                    EX_D_medium      -0.0      -0.0
# model_a_to_community_biomass  model_a_to_community_biomass       0.0       0.0
# model_b_TP_A_model_b_e              model_b_TP_A_model_b_e       0.0       0.0
# model_b_TP_B_model_b_e              model_b_TP_B_model_b_e       0.0       0.0
# model_b_TP_C_model_b_e              model_b_TP_C_model_b_e       0.0       0.0
# model_b_TP_D_model_b_e              model_b_TP_D_model_b_e       0.0       0.0
# model_b_to_community_biomass  model_b_to_community_biomass       0.0       0.0
# community_biomass                        community_biomass       0.0       0.0

# %% [markdown]
# With loopless FVA, PyCoMo correctly calculates 0 flux for all reactions, when no medium is present.

# %%
# %%time
com_model_obj_toy.medium = {'EX_A_medium': 1000.0, 'EX_D_medium': 1000.0}
com_model_obj_toy.apply_medium()
with com_model_obj_toy.model:
    fva = com_model_obj_toy.run_fva(reactions=com_model_obj_toy.model.reactions, fraction_of_optimum=1., loopless=True)
fva
# Out:
# 2024-07-08 15:15:59,343 - pycomo.helper.multiprocess - INFO - Processed 66.67% of fva steps
# CPU times: total: 156 ms
# Wall time: 8.47 s
#                                                reaction_id  min_flux  max_flux
# model_a_TP_A_model_a_e              model_a_TP_A_model_a_e     500.0     500.0
# model_a_TP_B_model_a_e              model_a_TP_B_model_a_e       0.0       0.0
# model_a_TP_C_model_a_e              model_a_TP_C_model_a_e       0.0       0.0
# model_a_TP_D_model_a_e              model_a_TP_D_model_a_e     500.0     500.0
# EX_A_medium                                    EX_A_medium   -1000.0   -1000.0
# EX_B_medium                                    EX_B_medium       0.0      -0.0
# EX_C_medium                                    EX_C_medium       0.0      -0.0
# EX_D_medium                                    EX_D_medium   -1000.0   -1000.0
# model_a_to_community_biomass  model_a_to_community_biomass     500.0     500.0
# model_b_TP_A_model_b_e              model_b_TP_A_model_b_e     500.0     500.0
# model_b_TP_B_model_b_e              model_b_TP_B_model_b_e       0.0       0.0
# model_b_TP_C_model_b_e              model_b_TP_C_model_b_e       0.0       0.0
# model_b_TP_D_model_b_e              model_b_TP_D_model_b_e     500.0     500.0
# model_b_to_community_biomass  model_b_to_community_biomass     500.0     500.0
# community_biomass                        community_biomass    1000.0    1000.0

# %% [markdown]
# At maximum growht-rate, the reactions that are part of loops are not used, as this would lead to a decrease in growth-rate.

# %%
# %%time
com_model_obj_toy.medium = {'EX_A_medium': 1000.0, 'EX_D_medium': 1000.0}
com_model_obj_toy.apply_medium()
with com_model_obj_toy.model:
    fva = com_model_obj_toy.run_fva(reactions=com_model_obj_toy.model.reactions, fraction_of_optimum=0., loopless=True)
fva
# Out:
# 2024-07-08 15:16:07,787 - pycomo.helper.multiprocess - INFO - Processed 66.67% of fva steps
# CPU times: total: 125 ms
# Wall time: 8.4 s
#                                                reaction_id  min_flux  max_flux
# model_a_TP_A_model_a_e              model_a_TP_A_model_a_e       0.0     500.0
# model_a_TP_B_model_a_e              model_a_TP_B_model_a_e    -250.0     250.0
# model_a_TP_C_model_a_e              model_a_TP_C_model_a_e    -250.0     250.0
# model_a_TP_D_model_a_e              model_a_TP_D_model_a_e       0.0     500.0
# EX_A_medium                                    EX_A_medium   -1000.0       0.0
# EX_B_medium                                    EX_B_medium       0.0     500.0
# EX_C_medium                                    EX_C_medium       0.0     500.0
# EX_D_medium                                    EX_D_medium   -1000.0       0.0
# model_a_to_community_biomass  model_a_to_community_biomass       0.0     500.0
# model_b_TP_A_model_b_e              model_b_TP_A_model_b_e       0.0     500.0
# model_b_TP_B_model_b_e              model_b_TP_B_model_b_e    -250.0     250.0
# model_b_TP_C_model_b_e              model_b_TP_C_model_b_e    -250.0     250.0
# model_b_TP_D_model_b_e              model_b_TP_D_model_b_e       0.0     500.0
# model_b_to_community_biomass  model_b_to_community_biomass       0.0     500.0
# community_biomass                        community_biomass       0.0    1000.0

# %% [markdown]
# However, there are valid flux configurations where the "loopy" reactions can carry flux, with both directions being viable without the use of loops.

# %%
# %%time
com_model_obj_toy.medium = {'EX_A_medium': 1000.0, 'EX_D_medium': 1000.0}
com_model_obj_toy.apply_medium()
with com_model_obj_toy.model:
    fva = com_model_obj_toy.run_fva(reactions=com_model_obj_toy.model.reactions, fraction_of_optimum=0.8, loopless=True)
fva
# Out:
# 2024-07-08 15:16:16,407 - pycomo.helper.multiprocess - INFO - Processed 66.67% of fva steps
# CPU times: total: 188 ms
# Wall time: 8.6 s
#                                                reaction_id  min_flux  max_flux
# model_a_TP_A_model_a_e              model_a_TP_A_model_a_e     300.0     500.0
# model_a_TP_B_model_a_e              model_a_TP_B_model_a_e    -200.0     200.0
# model_a_TP_C_model_a_e              model_a_TP_C_model_a_e    -100.0     100.0
# model_a_TP_D_model_a_e              model_a_TP_D_model_a_e     400.0     500.0
# EX_A_medium                                    EX_A_medium   -1000.0    -800.0
# EX_B_medium                                    EX_B_medium       0.0     200.0
# EX_C_medium                                    EX_C_medium       0.0     200.0
# EX_D_medium                                    EX_D_medium   -1000.0    -800.0
# model_a_to_community_biomass  model_a_to_community_biomass     400.0     500.0
# model_b_TP_A_model_b_e              model_b_TP_A_model_b_e     300.0     500.0
# model_b_TP_B_model_b_e              model_b_TP_B_model_b_e    -200.0     200.0
# model_b_TP_C_model_b_e              model_b_TP_C_model_b_e    -100.0     100.0
# model_b_TP_D_model_b_e              model_b_TP_D_model_b_e     400.0     500.0
# model_b_to_community_biomass  model_b_to_community_biomass     400.0     500.0
# community_biomass                        community_biomass     800.0    1000.0

# %% [markdown]
# The example of 80% of maximum growth-rate shows, that the loopless solution scales down the flux of the "loopy" reactions, to the level where they can be active without decreasing the maximum growth-rate below the 80% threshold.

# %%
# %%time
com_model_obj_toy.medium = {'EX_A_medium': 1000.0, 'EX_D_medium': 1000.0}
com_model_obj_toy.apply_medium()
with com_model_obj_toy.model:
    fva = com_model_obj_toy.run_fva(reactions=com_model_obj_toy.model.reactions, composition_agnostic=True, fraction_of_optimum=0., loopless=True)
fva
# Out:
# fixing mu_c
# (0.0, 1000.0)
# {<Metabolite cpd11416_medium at 0x1636c986f70>: -1}
# {<Metabolite model_a_cpd11416_model_a_medium at 0x1636c921730>: -1, <Metabolite model_a_to_community_biomass_ub at 0x1636c958070>: -0.01, <Metabolite cpd11416_medium at 0x1636c986f70>: 1}
# {<Metabolite model_b_to_community_biomass_ub at 0x1636c97e7c0>: -0.01, <Metabolite model_b_cpd11416_model_b_medium at 0x1636c8b8ca0>: -1, <Metabolite cpd11416_medium at 0x1636c986f70>: 1}
# 2024-07-08 15:16:25,482 - pycomo.helper.multiprocess - INFO - Processed 66.67% of fva steps
# CPU times: total: 172 ms
# Wall time: 9.06 s
#                                                reaction_id  min_flux  max_flux
# model_a_TP_A_model_a_e              model_a_TP_A_model_a_e       0.0    1000.0
# model_a_TP_B_model_a_e              model_a_TP_B_model_a_e    -500.0     250.0
# model_a_TP_C_model_a_e              model_a_TP_C_model_a_e    -500.0       0.0
# model_a_TP_D_model_a_e              model_a_TP_D_model_a_e       0.0       0.0
# EX_A_medium                                    EX_A_medium   -1000.0       0.0
# EX_B_medium                                    EX_B_medium       0.0     500.0
# EX_C_medium                                    EX_C_medium       0.0     500.0
# EX_D_medium                                    EX_D_medium       0.0       0.0
# model_a_to_community_biomass  model_a_to_community_biomass       0.0       0.0
# model_b_TP_A_model_b_e              model_b_TP_A_model_b_e       0.0    1000.0
# model_b_TP_B_model_b_e              model_b_TP_B_model_b_e    -500.0       0.0
# model_b_TP_C_model_b_e              model_b_TP_C_model_b_e    -500.0       0.0
# model_b_TP_D_model_b_e              model_b_TP_D_model_b_e       0.0       0.0
# model_b_to_community_biomass  model_b_to_community_biomass       0.0       0.0
# community_biomass                        community_biomass       0.0       0.0

# %%
# %%time
com_model_obj_toy.convert_to_fixed_growth_rate(1.0)
com_model_obj_toy.medium = {'EX_A_medium': 1000.0, 'EX_D_medium': 1000.0}
com_model_obj_toy.apply_medium()

with com_model_obj_toy.model:
    fva = com_model_obj_toy.run_fva(reactions=com_model_obj_toy.model.reactions, composition_agnostic=True, fraction_of_optimum=0., loopless=True, processes=1)
fva
# Out:
# has fixed mu_c
# (0.0, 1000.0)
# {<Metabolite cpd11416_medium at 0x1bd0814dd30>: -1}
# (0, 1000.0)
# {<Metabolite model_a_cpd11416_model_a_medium at 0x1bd08156dc0>: -1, <Metabolite model_a_to_community_biomass_ub at 0x1bd081a66d0>: -0.01, <Metabolite cpd11416_medium at 0x1bd0814dd30>: 1}
# {<Metabolite f_final_met at 0x1bd0817de20>: 1, <Metabolite model_a_TP_A_model_a_e_lb at 0x1bd081a6130>: 10.0, <Metabolite model_a_TP_A_model_a_e_ub at 0x1bd081a64c0>: 10.0, <Metabolite model_a_TP_B_model_a_e_lb at 0x1bd081a60a0>: 10.0, <Metabolite model_a_TP_B_model_a_e_ub at 0x1bd081a6490>: 10.0, <Metabolite model_a_TP_C_model_a_e_lb at 0x1bd081a6400>: 10.0, <Metabolite model_a_TP_C_model_a_e_ub at 0x1bd081a6340>: 10.0, <Metabolite model_a_TP_D_model_a_e_lb at 0x1bd081a63d0>: 10.0, <Metabolite model_a_TP_D_model_a_e_ub at 0x1bd081a63a0>: 10.0, <Metabolite model_a_TP_A_ub at 0x1bd081a6310>: 10.0, <Metabolite model_a_TP_B_lb at 0x1bd081a62b0>: 5.0, <Metabolite model_a_TP_B_ub at 0x1bd081a6280>: 10.0, <Metabolite model_a_TP_C_lb at 0x1bd081a62e0>: 5.0, <Metabolite model_a_TP_C_ub at 0x1bd081a6550>: 10.0, <Metabolite model_a_TP_D_ub at 0x1bd081a65b0>: 10.0, <Metabolite model_a_bio_ub at 0x1bd081a6640>: 10.0, <Metabolite model_a_v1_model_a_c_ub at 0x1bd081a6430>: 10.0, <Metabolite model_a_v2_model_a_c_lb at 0x1bd081a6790>: 10.0, <Metabolite model_a_v2_model_a_c_ub at 0x1bd081a65e0>: 10.0, <Metabolite model_a_to_community_biomass_ub at 0x1bd081a66d0>: 10.0}
# (0, 1000.0)
# {<Metabolite model_b_to_community_biomass_ub at 0x1bd080fefa0>: -0.01, <Metabolite model_b_cpd11416_model_b_medium at 0x1bd080fe4c0>: -1, <Metabolite cpd11416_medium at 0x1bd0814dd30>: 1}
# {<Metabolite f_final_met at 0x1bd0817de20>: 1, <Metabolite model_b_TP_A_model_b_e_lb at 0x1bd080c1d60>: 10.0, <Metabolite model_b_TP_A_model_b_e_ub at 0x1bd080c1df0>: 10.0, <Metabolite model_b_TP_B_model_b_e_lb at 0x1bd080f7100>: 10.0, <Metabolite model_b_TP_B_model_b_e_ub at 0x1bd080f7190>: 10.0, <Metabolite model_b_TP_C_model_b_e_lb at 0x1bd080f7460>: 10.0, <Metabolite model_b_TP_C_model_b_e_ub at 0x1bd080f74f0>: 10.0, <Metabolite model_b_TP_D_model_b_e_lb at 0x1bd080f77c0>: 10.0, <Metabolite model_b_TP_D_model_b_e_ub at 0x1bd080f7850>: 10.0, <Metabolite model_b_TP_A_ub at 0x1bd080f7a90>: 10.0, <Metabolite model_b_TP_B_lb at 0x1bd080f7cd0>: 5.0, <Metabolite model_b_TP_B_ub at 0x1bd080f7d60>: 10.0, <Metabolite model_b_TP_C_lb at 0x1bd080f7fa0>: 5.0, <Metabolite model_b_TP_C_ub at 0x1bd080fe070>: 10.0, <Metabolite model_b_TP_D_ub at 0x1bd080fe2b0>: 10.0, <Metabolite model_b_bio_ub at 0x1bd080fe4f0>: 10.0, <Metabolite model_b_v1_model_b_c_ub at 0x1bd080fe700>: 10.0, <Metabolite model_b_v2_model_b_c_lb at 0x1bd080fe8b0>: 10.0, <Metabolite model_b_v2_model_b_c_ub at 0x1bd080fe8e0>: 10.0, <Metabolite model_b_to_community_biomass_ub at 0x1bd080fefa0>: 10.0}
# Objective
# =========
# 1.0 model_a_to_community_biomass = 1000.0
#
# Uptake
# ------
# Metabolite    Reaction Flux  C-Number C-Flux
#   A_medium EX_A_medium 1000         0  0.00%
#   D_medium EX_D_medium 1000         0  0.00%
#
# Secretion
# ---------
#                Metabolite                     Reaction  Flux  C-Number C-Flux
# model_a_TP_A_model_a_e_lb SK_model_a_TP_A_model_a_e_lb   -20         0  0.00%
#           model_a_TP_B_lb           SK_model_a_TP_B_lb    -5         0  0.00%
# model_a_TP_B_model_a_e_lb SK_model_a_TP_B_model_a_e_lb   -10         0  0.00%
# model_a_TP_B_model_a_e_ub SK_model_a_TP_B_model_a_e_ub   -10         0  0.00%
#           model_a_TP_B_ub           SK_model_a_TP_B_ub   -10         0  0.00%
#           model_a_TP_C_lb           SK_model_a_TP_C_lb    -5         0  0.00%
# model_a_TP_C_model_a_e_lb SK_model_a_TP_C_model_a_e_lb   -10         0  0.00%
# model_a_TP_C_model_a_e_ub SK_model_a_TP_C_model_a_e_ub   -10         0  0.00%
#           model_a_TP_C_ub           SK_model_a_TP_C_ub   -10         0  0.00%
# model_a_TP_D_model_a_e_lb SK_model_a_TP_D_model_a_e_lb   -20         0  0.00%
#   model_a_v2_model_a_c_lb   SK_model_a_v2_model_a_c_lb   -20         0  0.00%
#           cpd11416_medium            community_biomass -1000         0  0.00%
#               f_final_met                      f_final    -1         0  0.00%
# 2024-07-08 16:35:49,618 - pycomo.helper.multiprocess - DEBUG - Summary before context:
# Objective
# =========
# 1.0 model_a_to_community_biomass = 1000.0
#
# Uptake
# ------
# Metabolite    Reaction Flux  C-Number C-Flux
#   A_medium EX_A_medium 1000         0  0.00%
#   D_medium EX_D_medium 1000         0  0.00%
#
# Secretion
# ---------
#      Metabolite          Reaction  Flux  C-Number C-Flux
# cpd11416_medium community_biomass -1000         0  0.00%
#
# 2024-07-08 16:35:49,635 - pycomo.helper.multiprocess - DEBUG - Summary at start:
# Objective
# =========
# 1.0 model_a_to_community_biomass = 1000.0
#
# Uptake
# ------
# Metabolite    Reaction Flux  C-Number C-Flux
#   A_medium EX_A_medium 1000         0  0.00%
#   D_medium EX_D_medium 1000         0  0.00%
#
# Secretion
# ---------
#      Metabolite          Reaction  Flux  C-Number C-Flux
# cpd11416_medium community_biomass -1000         0  0.00%
#                  reaction  min_flux  max_flux
# 0  model_a_TP_B_model_a_e    -500.0     500.0
# 1  model_a_TP_C_model_a_e    -500.0     500.0
# 2            model_a_TP_B    -500.0     500.0
# 3            model_a_TP_C    -500.0     500.0
# 4    model_a_v2_model_a_c    -500.0     500.0
# 5  model_b_TP_B_model_b_e    -500.0     500.0
# 6  model_b_TP_C_model_b_e    -500.0     500.0
# 7            model_b_TP_B    -500.0     500.0
# 8            model_b_TP_C    -500.0     500.0
# 9    model_b_v2_model_b_c    -500.0     500.0
# Summary after get loops in run fva:
# Objective
# =========
# 1.0 model_a_to_community_biomass = 1000.0
#
# Uptake
# ------
# Metabolite    Reaction Flux  C-Number C-Flux
#   A_medium EX_A_medium 1000         0  0.00%
#   D_medium EX_D_medium 1000         0  0.00%
#
# Secretion
# ---------
#      Metabolite          Reaction  Flux  C-Number C-Flux
# cpd11416_medium community_biomass -1000         0  0.00%
# 2024-07-08 16:35:53,865 - pycomo.helper.multiprocess - DEBUG - Summary after get loops:
# Objective
# =========
# 1.0 model_a_to_community_biomass = 1000.0
#
# Uptake
# ------
# Metabolite    Reaction Flux  C-Number C-Flux
#   A_medium EX_A_medium 1000         0  0.00%
#   D_medium EX_D_medium 1000         0  0.00%
#
# Secretion
# ---------
#      Metabolite          Reaction  Flux  C-Number C-Flux
# cpd11416_medium community_biomass -1000         0  0.00%
#
# 2024-07-08 16:35:53,884 - pycomo.helper.multiprocess - DEBUG - Summary after setting objective:
# Objective
# =========
# 1.0 model_a_to_community_biomass = 1000.0
#
# Uptake
# ------
# Metabolite    Reaction Flux  C-Number C-Flux
#   A_medium EX_A_medium 1000         0  0.00%
#   D_medium EX_D_medium 1000         0  0.00%
#
# Secretion
# ---------
#      Metabolite          Reaction  Flux  C-Number C-Flux
# cpd11416_medium community_biomass -1000         0  0.00%
#
# 2024-07-08 16:35:53,885 - pycomo.helper.multiprocess - DEBUG - Running with 1 processes
# 2024-07-08 16:35:53,886 - pycomo.helper.multiprocess - DEBUG - _init_worker finished in 0.0010004043579101562
# 2024-07-08 16:35:53,887 - pycomo.helper.multiprocess - INFO - model_a_TP_A_model_a_e is not in loopless candidates
# 2024-07-08 16:35:53,889 - pycomo.helper.multiprocess - DEBUG - model_a_TP_A_model_a_e solution min flux 0.0
# 2024-07-08 16:35:53,891 - pycomo.helper.multiprocess - DEBUG - model_a_TP_A_model_a_e solution max flux 1000.0
# 2024-07-08 16:35:53,891 - pycomo.helper.multiprocess - INFO - Loop correction will be applied on model_a_TP_B_model_a_e
# 2024-07-08 16:35:53,893 - pycomo.helper.multiprocess - DEBUG - model_a_TP_B_model_a_e Starting loop correction
# 2024-07-08 16:35:53,894 - pycomo.helper.multiprocess - DEBUG - Starting add loopless constraints
# 2024-07-08 16:35:53,894 - pycomo.helper.multiprocess - DEBUG - Add exchange constraints
# 2024-07-08 16:35:53,895 - pycomo.helper.multiprocess - DEBUG - Add ko_candidate constraints
# 2024-07-08 16:35:53,897 - pycomo.helper.multiprocess - DEBUG - Add remaining constraints
# 2024-07-08 16:35:53,898 - pycomo.helper.multiprocess - DEBUG - Set coefficients
# 2024-07-08 16:35:53,899 - pycomo.helper.multiprocess - DEBUG - add loopless constraints finished
# 2024-07-08 16:35:53,899 - pycomo.helper.multiprocess - DEBUG - model_a_TP_B_model_a_e Optimize for loopless flux
# 2024-07-08 16:35:53,901 - pycomo.helper.multiprocess - DEBUG - model_a_TP_B_model_a_e Optimization for loopless flux finished
# 2024-07-08 16:35:53,904 - pycomo.helper.multiprocess - DEBUG - model_a_TP_B_model_a_e solution min flux -500.0
# 2024-07-08 16:35:53,906 - pycomo.helper.multiprocess - DEBUG - model_a_TP_B_model_a_e Starting loop correction
# 2024-07-08 16:35:53,906 - pycomo.helper.multiprocess - DEBUG - Starting add loopless constraints
# 2024-07-08 16:35:53,906 - pycomo.helper.multiprocess - DEBUG - Add exchange constraints
# 2024-07-08 16:35:53,907 - pycomo.helper.multiprocess - DEBUG - Add ko_candidate constraints
# 2024-07-08 16:35:53,909 - pycomo.helper.multiprocess - DEBUG - Add remaining constraints
# 2024-07-08 16:35:53,910 - pycomo.helper.multiprocess - DEBUG - Set coefficients
# 2024-07-08 16:35:53,911 - pycomo.helper.multiprocess - DEBUG - add loopless constraints finished
# 2024-07-08 16:35:53,911 - pycomo.helper.multiprocess - DEBUG - model_a_TP_B_model_a_e Optimize for loopless flux
# 2024-07-08 16:35:53,914 - pycomo.helper.multiprocess - DEBUG - model_a_TP_B_model_a_e Optimization for loopless flux finished
# 2024-07-08 16:35:53,918 - pycomo.helper.multiprocess - DEBUG - model_a_TP_B_model_a_e solution max flux 333.33333333333326
# 2024-07-08 16:35:53,918 - pycomo.helper.multiprocess - INFO - Loop correction will be applied on model_a_TP_C_model_a_e
# 2024-07-08 16:35:53,920 - pycomo.helper.multiprocess - DEBUG - model_a_TP_C_model_a_e Starting loop correction
# 2024-07-08 16:35:53,920 - pycomo.helper.multiprocess - DEBUG - Starting add loopless constraints
# 2024-07-08 16:35:53,921 - pycomo.helper.multiprocess - DEBUG - Add exchange constraints
# 2024-07-08 16:35:53,922 - pycomo.helper.multiprocess - DEBUG - Add ko_candidate constraints
# 2024-07-08 16:35:53,923 - pycomo.helper.multiprocess - DEBUG - Add remaining constraints
# 2024-07-08 16:35:53,925 - pycomo.helper.multiprocess - DEBUG - Set coefficients
# 2024-07-08 16:35:53,925 - pycomo.helper.multiprocess - DEBUG - add loopless constraints finished
# 2024-07-08 16:35:53,926 - pycomo.helper.multiprocess - DEBUG - model_a_TP_C_model_a_e Optimize for loopless flux
# 2024-07-08 16:35:53,928 - pycomo.helper.multiprocess - DEBUG - model_a_TP_C_model_a_e Optimization for loopless flux finished
# 2024-07-08 16:35:53,932 - pycomo.helper.multiprocess - DEBUG - model_a_TP_C_model_a_e solution min flux -500.0
# 2024-07-08 16:35:53,934 - pycomo.helper.multiprocess - DEBUG - model_a_TP_C_model_a_e Starting loop correction
# 2024-07-08 16:35:53,934 - pycomo.helper.multiprocess - DEBUG - Starting add loopless constraints
# 2024-07-08 16:35:53,935 - pycomo.helper.multiprocess - DEBUG - Add exchange constraints
# 2024-07-08 16:35:53,936 - pycomo.helper.multiprocess - DEBUG - Add ko_candidate constraints
# 2024-07-08 16:35:53,937 - pycomo.helper.multiprocess - DEBUG - Add remaining constraints
# 2024-07-08 16:35:53,939 - pycomo.helper.multiprocess - DEBUG - Set coefficients
# 2024-07-08 16:35:53,939 - pycomo.helper.multiprocess - DEBUG - add loopless constraints finished
# 2024-07-08 16:35:53,939 - pycomo.helper.multiprocess - DEBUG - model_a_TP_C_model_a_e Optimize for loopless flux
# 2024-07-08 16:35:53,942 - pycomo.helper.multiprocess - DEBUG - model_a_TP_C_model_a_e Optimization for loopless flux finished
# 2024-07-08 16:35:53,945 - pycomo.helper.multiprocess - DEBUG - model_a_TP_C_model_a_e solution max flux 166.66666666666663
# 2024-07-08 16:35:53,945 - pycomo.helper.multiprocess - INFO - model_a_TP_D_model_a_e is not in loopless candidates
# 2024-07-08 16:35:53,948 - pycomo.helper.multiprocess - DEBUG - model_a_TP_D_model_a_e solution min flux 0.0
# 2024-07-08 16:35:53,950 - pycomo.helper.multiprocess - DEBUG - model_a_TP_D_model_a_e solution max flux 1000.0
# 2024-07-08 16:35:53,950 - pycomo.helper.multiprocess - INFO - EX_A_medium is not in loopless candidates
# 2024-07-08 16:35:53,952 - pycomo.helper.multiprocess - DEBUG - EX_A_medium solution min flux -1000.0
# 2024-07-08 16:35:53,954 - pycomo.helper.multiprocess - DEBUG - EX_A_medium solution max flux 0.0
# 2024-07-08 16:35:53,954 - pycomo.helper.multiprocess - INFO - EX_B_medium is not in loopless candidates
# 2024-07-08 16:35:53,956 - pycomo.helper.multiprocess - DEBUG - EX_B_medium solution min flux 0.0
# 2024-07-08 16:35:53,958 - pycomo.helper.multiprocess - DEBUG - EX_B_medium solution max flux 500.0
# 2024-07-08 16:35:53,958 - pycomo.helper.multiprocess - INFO - EX_C_medium is not in loopless candidates
# 2024-07-08 16:35:53,960 - pycomo.helper.multiprocess - DEBUG - EX_C_medium solution min flux 0.0
# 2024-07-08 16:35:53,961 - pycomo.helper.multiprocess - DEBUG - EX_C_medium solution max flux 500.0
# 2024-07-08 16:35:53,961 - pycomo.helper.multiprocess - INFO - EX_D_medium is not in loopless candidates
# 2024-07-08 16:35:53,964 - pycomo.helper.multiprocess - DEBUG - EX_D_medium solution min flux -1000.0
# 2024-07-08 16:35:53,966 - pycomo.helper.multiprocess - DEBUG - EX_D_medium solution max flux 0.0
# 2024-07-08 16:35:53,966 - pycomo.helper.multiprocess - INFO - model_a_to_community_biomass is not in loopless candidates
# 2024-07-08 16:35:53,969 - pycomo.helper.multiprocess - DEBUG - model_a_to_community_biomass solution min flux 0.0
# 2024-07-08 16:35:53,970 - pycomo.helper.multiprocess - DEBUG - model_a_to_community_biomass solution max flux 1000.0
# 2024-07-08 16:35:53,970 - pycomo.helper.multiprocess - INFO - model_b_TP_A_model_b_e is not in loopless candidates
# 2024-07-08 16:35:53,972 - pycomo.helper.multiprocess - DEBUG - model_b_TP_A_model_b_e solution min flux 0.0
# 2024-07-08 16:35:53,974 - pycomo.helper.multiprocess - DEBUG - model_b_TP_A_model_b_e solution max flux 1000.0
# 2024-07-08 16:35:53,974 - pycomo.helper.multiprocess - INFO - Processed 66.67% of fva steps
# 2024-07-08 16:35:53,974 - pycomo.helper.multiprocess - INFO - Loop correction will be applied on model_b_TP_B_model_b_e
# 2024-07-08 16:35:53,976 - pycomo.helper.multiprocess - DEBUG - model_b_TP_B_model_b_e Starting loop correction
# 2024-07-08 16:35:53,979 - pycomo.helper.multiprocess - DEBUG - Starting add loopless constraints
# 2024-07-08 16:35:53,980 - pycomo.helper.multiprocess - DEBUG - Add exchange constraints
# 2024-07-08 16:35:53,981 - pycomo.helper.multiprocess - DEBUG - Add ko_candidate constraints
# 2024-07-08 16:35:53,982 - pycomo.helper.multiprocess - DEBUG - Add remaining constraints
# 2024-07-08 16:35:53,984 - pycomo.helper.multiprocess - DEBUG - Set coefficients
# 2024-07-08 16:35:53,984 - pycomo.helper.multiprocess - DEBUG - add loopless constraints finished
# 2024-07-08 16:35:53,985 - pycomo.helper.multiprocess - DEBUG - model_b_TP_B_model_b_e Optimize for loopless flux
# 2024-07-08 16:35:53,987 - pycomo.helper.multiprocess - DEBUG - model_b_TP_B_model_b_e Optimization for loopless flux finished
# 2024-07-08 16:35:53,990 - pycomo.helper.multiprocess - DEBUG - model_b_TP_B_model_b_e solution min flux -500.0
# 2024-07-08 16:35:53,992 - pycomo.helper.multiprocess - DEBUG - model_b_TP_B_model_b_e Starting loop correction
# 2024-07-08 16:35:53,992 - pycomo.helper.multiprocess - DEBUG - Starting add loopless constraints
# 2024-07-08 16:35:53,993 - pycomo.helper.multiprocess - DEBUG - Add exchange constraints
# 2024-07-08 16:35:53,993 - pycomo.helper.multiprocess - DEBUG - Add ko_candidate constraints
# 2024-07-08 16:35:53,995 - pycomo.helper.multiprocess - DEBUG - Add remaining constraints
# 2024-07-08 16:35:53,997 - pycomo.helper.multiprocess - DEBUG - Set coefficients
# 2024-07-08 16:35:53,997 - pycomo.helper.multiprocess - DEBUG - add loopless constraints finished
# 2024-07-08 16:35:53,998 - pycomo.helper.multiprocess - DEBUG - model_b_TP_B_model_b_e Optimize for loopless flux
# 2024-07-08 16:35:54,000 - pycomo.helper.multiprocess - DEBUG - model_b_TP_B_model_b_e Optimization for loopless flux finished
# 2024-07-08 16:35:54,003 - pycomo.helper.multiprocess - DEBUG - model_b_TP_B_model_b_e solution max flux 333.33333333333326
# 2024-07-08 16:35:54,004 - pycomo.helper.multiprocess - INFO - Loop correction will be applied on model_b_TP_C_model_b_e
# 2024-07-08 16:35:54,006 - pycomo.helper.multiprocess - DEBUG - model_b_TP_C_model_b_e Starting loop correction
# 2024-07-08 16:35:54,006 - pycomo.helper.multiprocess - DEBUG - Starting add loopless constraints
# 2024-07-08 16:35:54,007 - pycomo.helper.multiprocess - DEBUG - Add exchange constraints
# 2024-07-08 16:35:54,008 - pycomo.helper.multiprocess - DEBUG - Add ko_candidate constraints
# 2024-07-08 16:35:54,009 - pycomo.helper.multiprocess - DEBUG - Add remaining constraints
# 2024-07-08 16:35:54,011 - pycomo.helper.multiprocess - DEBUG - Set coefficients
# 2024-07-08 16:35:54,011 - pycomo.helper.multiprocess - DEBUG - add loopless constraints finished
# 2024-07-08 16:35:54,012 - pycomo.helper.multiprocess - DEBUG - model_b_TP_C_model_b_e Optimize for loopless flux
# 2024-07-08 16:35:54,014 - pycomo.helper.multiprocess - DEBUG - model_b_TP_C_model_b_e Optimization for loopless flux finished
# 2024-07-08 16:35:54,018 - pycomo.helper.multiprocess - DEBUG - model_b_TP_C_model_b_e solution min flux -500.0
# 2024-07-08 16:35:54,020 - pycomo.helper.multiprocess - DEBUG - model_b_TP_C_model_b_e Starting loop correction
# 2024-07-08 16:35:54,020 - pycomo.helper.multiprocess - DEBUG - Starting add loopless constraints
# 2024-07-08 16:35:54,020 - pycomo.helper.multiprocess - DEBUG - Add exchange constraints
# 2024-07-08 16:35:54,021 - pycomo.helper.multiprocess - DEBUG - Add ko_candidate constraints
# 2024-07-08 16:35:54,023 - pycomo.helper.multiprocess - DEBUG - Add remaining constraints
# 2024-07-08 16:35:54,025 - pycomo.helper.multiprocess - DEBUG - Set coefficients
# 2024-07-08 16:35:54,025 - pycomo.helper.multiprocess - DEBUG - add loopless constraints finished
# 2024-07-08 16:35:54,025 - pycomo.helper.multiprocess - DEBUG - model_b_TP_C_model_b_e Optimize for loopless flux
# 2024-07-08 16:35:54,027 - pycomo.helper.multiprocess - DEBUG - model_b_TP_C_model_b_e Optimization for loopless flux finished
# 2024-07-08 16:35:54,031 - pycomo.helper.multiprocess - DEBUG - model_b_TP_C_model_b_e solution max flux 333.33333333333337
# 2024-07-08 16:35:54,032 - pycomo.helper.multiprocess - INFO - model_b_TP_D_model_b_e is not in loopless candidates
# 2024-07-08 16:35:54,034 - pycomo.helper.multiprocess - DEBUG - model_b_TP_D_model_b_e solution min flux 0.0
# 2024-07-08 16:35:54,036 - pycomo.helper.multiprocess - DEBUG - model_b_TP_D_model_b_e solution max flux 1000.0
# 2024-07-08 16:35:54,036 - pycomo.helper.multiprocess - INFO - model_b_to_community_biomass is not in loopless candidates
# 2024-07-08 16:35:54,038 - pycomo.helper.multiprocess - DEBUG - model_b_to_community_biomass solution min flux 0.0
# 2024-07-08 16:35:54,039 - pycomo.helper.multiprocess - DEBUG - model_b_to_community_biomass solution max flux 1000.0
# 2024-07-08 16:35:54,040 - pycomo.helper.multiprocess - INFO - community_biomass is not in loopless candidates
# 2024-07-08 16:35:54,042 - pycomo.helper.multiprocess - DEBUG - community_biomass solution min flux -0.0
# 2024-07-08 16:35:54,043 - pycomo.helper.multiprocess - DEBUG - community_biomass solution max flux 1000.0
# CPU times: total: 469 ms
# Wall time: 8.75 s
#                                                reaction_id  min_flux  \
# model_a_TP_A_model_a_e              model_a_TP_A_model_a_e       0.0
# model_a_TP_B_model_a_e              model_a_TP_B_model_a_e    -500.0
# model_a_TP_C_model_a_e              model_a_TP_C_model_a_e    -500.0
# model_a_TP_D_model_a_e              model_a_TP_D_model_a_e       0.0
# EX_A_medium                                    EX_A_medium   -1000.0
# EX_B_medium                                    EX_B_medium       0.0
# EX_C_medium                                    EX_C_medium       0.0
# EX_D_medium                                    EX_D_medium   -1000.0
# model_a_to_community_biomass  model_a_to_community_biomass       0.0
# model_b_TP_A_model_b_e              model_b_TP_A_model_b_e       0.0
# model_b_TP_B_model_b_e              model_b_TP_B_model_b_e    -500.0
# model_b_TP_C_model_b_e              model_b_TP_C_model_b_e    -500.0
# model_b_TP_D_model_b_e              model_b_TP_D_model_b_e       0.0
# model_b_to_community_biomass  model_b_to_community_biomass       0.0
# community_biomass                        community_biomass      -0.0
#
#                                  max_flux
# model_a_TP_A_model_a_e        1000.000000
# model_a_TP_B_model_a_e         333.333333
# model_a_TP_C_model_a_e         166.666667
# model_a_TP_D_model_a_e        1000.000000
# EX_A_medium                      0.000000
# EX_B_medium                    500.000000
# EX_C_medium                    500.000000
# EX_D_medium                      0.000000
# model_a_to_community_biomass  1000.000000
# model_b_TP_A_model_b_e        1000.000000
# model_b_TP_B_model_b_e         333.333333
# model_b_TP_C_model_b_e         333.333333
# model_b_TP_D_model_b_e        1000.000000
# model_b_to_community_biomass  1000.000000
# community_biomass             1000.000000
